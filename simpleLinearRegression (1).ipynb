# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("/content/Salary_Data.csv")
#print(dataset)

# %%
x=dataset.iloc[:,:1].values
y=dataset.iloc[:,-1].values
# print(x)
# print(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=1)
#print(y_train)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
#print(x_train)
# Out:
# LinearRegression()

# %%
y_predict=regressor.predict(x_test)
print(y_predict)
# Out:
# [75074.50510972 91873.8056381  62008.38247653 81607.56642631
#  67608.14931932 89073.92221671]

# %% [markdown]
# prediction

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Years of experience')
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Years of experience')
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
#!git init
#!git add .
#!git commit -m"for test set"
#!  git config --global user.email "makokha.14460@students.kyu.ac.ke"
#!git config --global user.name"MAKOKHA-KWEYU-SADIKI"
#!git remote add origin https://github.com/MAKOKHA-KWEYU-SADIKI/multipleLinearRegression.git
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
